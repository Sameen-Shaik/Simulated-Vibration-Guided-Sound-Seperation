# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/mnt/WorkSpace/Repos/rag-powered-chatbot'

# %%
df_gender = pd.read_csv("Data/gender_submission.csv")
df_test = pd.read_csv("Data/test.csv")
df_train = pd.read_csv("Data/train.csv")

# %%
df_gender
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_merged = pd.concat([df_train, df_test])
df_merged.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
df = pd.merge(df_merged, df_gender, how='left', on='PassengerId')
df.drop(['Survived_y'], axis=1, inplace=True)
df
# Out:
#       PassengerId  Survived_x  Pclass  \
# 0               1         0.0       3
# 1               2         1.0       1
# 2               3         1.0       3
# 3               4         1.0       1
# 4               5         0.0       3
# ...           ...         ...     ...
# 1304         1305         NaN       3
# 1305         1306         NaN       1
# 1306         1307         NaN       3
# 1307         1308         NaN       3
# 1308         1309         NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
from langchain_ollama import OllamaLLM

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
from langchain_ollama.chat_models import ChatOllama

llm = OllamaLLM(model="llama3.2")
print(llm.invoke("Hello"))
# Out:
# Hello! It's nice to meet you. Is there something I can help you with or would you like to chat?

# %%
template = """
You are a data assistant.

Your job is to convert a natural language question into a valid pandas
filtering or aggregation expression.

The dataframe is named `df`.

Columns and dtypes:
{df.dtypes}

First 5 rows:
{df.head(5)}

User question:
"{query}"

Rules:
- Only output a valid Python pandas expression.
- Do NOT explain anything.
- Do NOT add backticks.
- Do NOT add comments.
- The expression must start with df.
- If aggregation is required (count, mean, sum), return the full pandas expression.

Examples:
Question: How many women survived?
Answer:
df[(df['Sex']=='female') & (df['Survived']==1)]

Question: What is the average fare in 1st class?
Answer:
df[df['Pclass']==1]['Fare'].mean()

Now generate the answer.
"""

# %%
template = """
You are a data assistant.

Your job is to convert a natural language question into a valid pandas
filtering or aggregation expression.

The dataframe is named `df`.

Columns and dtypes:
{dtypes}

First 5 rows:
{head}

User question:
"{query}"

Rules:
- Only output a valid Python pandas expression.
- Do NOT explain anything.
- Do NOT add backticks.
- Do NOT add comments.
- The expression must start with df.
- If aggregation is required (count, mean, sum), return the full pandas expression.

Examples:
Question: How many women survived?
Answer:
df[(df['Sex']=='female') & (df['Survived']==1)]

Question: What is the average fare in 1st class?
Answer:
df[df['Pclass']==1]['Fare'].mean()

Now generate the answer.
"""

# %%
def get_data(user_query):
    pass

# %%
def handle_conversation():
    context = ""
    print("This dataset is about Titanic dataset. What do you want to ask? \n(press 'q' to quit)")

    while True:
        user_input = input("you: ")

        if user_input == 'q':
            break
        result = chain.invoke({"context": context,
                               "dtypes": df.dtypes.to_string(),
                               "head": df.head(10).to_string(),
                               "query": user_input})
        print(f"Bot: {result}")
        generated_code = result.strip()
        output = eval(generated_code)
        print(f"output: {output}")
        context += f"\nUser: {user_input} \nAI: {result}"
handle_conversation()
# Out:
# This dataset is about Titanic dataset. What do you want to ask?
# (press 'q' to quit)
