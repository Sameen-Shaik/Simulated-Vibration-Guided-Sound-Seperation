# %%
import kagglehub
import shutil

# Download latest version
print("Downloading Dataset...")
path = kagglehub.dataset_download("vinayshanbhag/bird-song-data-set")

print("Path to dataset files:", path)

shutil.move(path, "./data/dataset_1")
print("Moved Dataset to cwd 'data/dataset_1'")
# Out:
# Downloading Dataset...
# Resuming download from 62914560 bytes (2179381788 bytes left)...
# Resuming download to /home/sameen/.cache/kagglehub/datasets/vinayshanbhag/bird-song-data-set/1.archive (62914560/2242296348) bytes left.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2.09G/2.09G [03:19<00:00, 10.9MB/s]
# Extracting files...
# Path to dataset files: /home/sameen/.cache/kagglehub/datasets/vinayshanbhag/bird-song-data-set/versions/1
# Moved Dataset to cwd 'data/dataset_1'

# %%
path
# Out:
# '/home/sameen/.cache/kagglehub/datasets/vinayshanbhag/bird-song-data-set/versions/1'
